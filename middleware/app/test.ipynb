# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_pickle("data/df.pkl")
df.head()
# Out:
#                                              description  popularity  \
# 1846   In the rail yards of Queens, contractors repai...       8.673
# 1341   A streetwise man flees South Central Los Angel...      15.079
# 1342   Set in the 22nd century, when a battered salva...      10.531
# 1840   College coeds in New York City, Al, the son of...      10.192
# 23239  On the eve of his wedding, a Manhattanite take...       1.326
#
#                             poster_path  vote_average  vote_count  tmdb_id  \
# 1846   /AtwXtU8CDWvVADgOwRkOSRZFPWI.jpg         6.187       347.0  19457.0
# 1341   /dP4fYCGQZzg17ta7FvLwJVCwwt9.jpg         6.412       453.0  10471.0
# 1342   /AmHGUjhgXnOYRYrF2ZYMtzfwxPe.jpg         4.957       299.0  10384.0
# 1840   /ptvHDZtJxj9kj1unae6ryoXsmud.jpg         5.200       205.0  10472.0
# 23239  /4G8TwEngXbAnuLKQvOZ2qbODnh5.jpg         4.300         3.0  97805.0
#
#        movieId           title  year  Adventure  ...  Musical  Western  \
# ...

# %%
list(df.popularity.sort_values(ascending=False))[10001]
# Out:
# 6.654

# %%
df[df.popularity >= list(df.popularity.sort_values(ascending=False))[10000]].index
# Out:
# Int64Index([ 1846,  1341,  1342,  1840,  1248,   789,  7778,    86,  1343,
#              3306,
#             ...
#             31218, 19174, 29514, 15676, 19768, 20874, 30233, 29515,  8655,
#             29677],
#            dtype='int64', length=10001)
